# %% [markdown]
# We are currently working in the following directory:

# %%
# !pwd
# Out:
# /c/Users/naoda/student-a7/jupyterlab_practice

# %% [markdown]
# To time how long it takes to run a Python cell, we could use the "timeit" command inside a cell as is shown below, followed by the proper use of the "timeit" command to time the following loop:
#
#
# ```
# %%timeit  # measure the performance for the following for loop
#
# for i in range(1_000_000):
#     i**2
# ```

# %%
# !jupyter nbconvert --to html --no-input question12.ipynb
# Out:
# [NbConvertApp] Converting notebook question12.ipynb to html
# [NbConvertApp] Writing 270713 bytes to question12.html
